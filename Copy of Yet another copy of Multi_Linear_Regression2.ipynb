# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from scipy.stats import probplot

# %%
df= pd.read_csv('https://raw.githubusercontent.com/WWasis/BSIS_XANDER-SOTELO/refs/heads/main/StudentsPerformance1.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
X_multi = df[["math score", "reading score"]]
y = df["writing score"]
model_multi = LinearRegression()
model_multi.fit(X_multi, y)
print("Intercept: ", model_multi.intercept_)
print("Coefficients: ", model_multi.coef_)
# Out:
# Intercept:  -1.1608443222254294
# Coefficients:  [0.06704516 0.93660305]

# %%
y_pred = model_multi.predict(X_multi)

# %%
print(y_pred)
# Out:
# [71.10182719 87.75954669 93.85051035 55.37665235 76.98962617 81.33741563
#  93.71642002 41.79489346 63.07264147 57.58305506 53.30433996 50.22432095
#  79.06193856 71.50409816 51.83137562 73.71050087 88.0968017  30.01726632
#  41.26056137 56.78257153 67.88974706 73.44232023 52.3657077  71.83729477
#  70.29931446 73.04207846 54.04183673 67.95679223 69.09453076 68.55816947
#  72.77389782 63.94219936 70.02910462 40.85829041 86.82700204 80.13466113
#  79.66534501 62.13400921 88.16181766 55.11050091 59.65942586 71.09979799
#  56.71552637 63.67401872 54.64118478 53.77365609 63.40583807 69.76295317
#  71.96935589 83.01151546 53.90571721 68.62724384 43.60308361 77.7941681
#  82.27401869 39.45237122 83.94811851 53.83867205 57.98735523 14.7614076
#  73.44434943 37.98143608 60.12874199 78.39351615 57.11779734 63.27377695
#  36.51050094 70.29728526 57.25188766 61.39651244 61.73376745 54.57616882
#  49.35476306 56.31528461 48.01791824 40.189868   25.20218993 77.25780681
# ...

# %%
print(y_pred.max())
# Out:
# 99.20397722883828

# %%
print(y_pred.min())
# Out:
# 14.761407601420663

# %%
y_pred_multi= model_multi.predict(X_multi)
residuals= y-y_pred_multi

# %%
# Plot the residuals
plt.scatter(y_pred, residuals, color="red")
plt.axhline(0, color="black", linestyle="--")
plt.xlabel("Predicted Writing Score")
plt.ylabel("Residuals")
plt.title("Residual Plot for Writing Score Prediction")
plt.show()

# %%
probplot(residuals, dist = "norm", plot=plt)
plt.title("Q-Q Plot")
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have your predicted scores (y_pred) and actual scores (y)
# Replace these with your actual data

y_pred = [80, 85, 90, 75, 95]  # Example predicted scores
y = [82, 87, 92, 78, 93]  # Example actual scores

plt.scatter(y_pred, y)
plt.xlabel("Predicted Writing Score")
plt.ylabel("Actual Writing Score")
plt.title("Comparison of Predicted vs. Actual Writing Scores")
plt.show()
